# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiainga157/Proyecto-UTEC/blob/feature-norm/Proyecto_Normativa_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

print('Librerias cargadas correctamente')
print(f'Version de pandas: {pd.__version__}')
print(f'Version de numpy: {np.__version__}')
print(f'Version de folium: {folium.__version__}')
# Out:
# Librerias cargadas correctamente
# Version de pandas: 2.2.2
# Version de numpy: 2.0.2
# Version de folium: 0.20.0

# %% [markdown]
# # 2. Carga de datos
#
#
# *   Carga de base de datos IPASH Suelo
# *   Carga de base de datos IPASH Agua
# *   Carga de base de datos IPASH Sedimento
# *   Carga de normativas
# *   Carga de datos para cobertura vegetal: MapBiomas + GEE (NDVI)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Componente suelo:
#URL de exportación: https://docs.google.com/spreadsheets/d/17zSeu4qP2TIJK7dy0MWKBqZOAkq24xCq/edit?usp=drive_link&ouid=110342148515634196231&rtpof=true&sd=true
URL_SUELO = 'https://docs.google.com/spreadsheets/d/17zSeu4qP2TIJK7dy0MWKBqZOAkq24xCq/export?format=xlsx'
suelo = pd.read_excel(URL_SUELO)
suelo.head()
# Out:
#                       Número de informe  \
# 0  INFORME N° 00003-2017-OEFA/DEAM-SSIM
# 1  INFORME N° 00003-2017-OEFA/DEAM-SSIM
# 2  INFORME N° 00003-2017-OEFA/DEAM-SSIM
# 3  INFORME N° 00003-2017-OEFA/DEAM-SSIM
# 4  INFORME N° 00003-2017-OEFA/DEAM-SSIM
#
#                              Nombre de la Evaluación             Etapa  \
# 0  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
# 1  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
# 2  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
# 3  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
# 4  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
#
#   Componente ambiental Procedencia de la Muestra  \
# 0                Suelo                     Suelo
# 1                Suelo                     Suelo
# 2                Suelo                     Suelo
# 3                Suelo                     Suelo
# 4                Suelo                     Suelo
#
#   Procedencia Especifica de la Muestra Nombre del punto    Este    Norte  \
# 0            Área de potencial interés      F05447-SU01  478216  9526380
# 1            Área de potencial interés      F05447-SU01  478216  9526380
# 2            Área de potencial interés      F05447-SU01  478216  9526380
# 3            Área de potencial interés      F05447-SU01  478216  9526380
# 4            Área de potencial interés      F05447-SU02  478224  9526389
#
#    Altitud  ...                           Descripción de ubicación  \
# 0      275  ...  Muestra puntual de suelo tomada a 1.3 m en dir...
# 1      275  ...  Muestra puntual de suelo tomada a 1.3 m en dir...
# 2      275  ...  Muestra puntual de suelo tomada a 1.3 m en dir...
# 3      275  ...  Muestra puntual de suelo tomada a 1.3 m en dir...
# 4      275  ...  Muestra puntual de suelo tomada a 8.4 m en dir...
#
#   Tipo de muestra Tipo de análisis Etapa de extracción secuencial  \
# 0          Simple        No aplica                      No aplica
# 1          Simple        No aplica                      No aplica
# 2          Simple        No aplica                      No aplica
# 3          Simple        No aplica                      No aplica
# 4          Simple        No aplica                      No aplica
#
#     Caracterización de la muestra    Fecha         Hora  Valor  \
# 0  Ensayo por cromatografía - HTP  11/7/17  11:12:00 AM    514
# 1  Ensayo por cromatografía - HTP  11/7/17  11:12:00 AM   3795
# 2  Ensayo por cromatografía - HTP  11/7/17  11:12:00 AM   <0.3
# 3  Ensayo por cromatografía - HTP  11/7/17  11:12:00 AM   4310
# 4  Ensayo por cromatografía - HTP  11/7/17  11:21:00 AM  <5.00
#
#                                     Parámetro Unidad de medida
# 0    Fracciones de Hidrocarburos F2 (C10-C28)            mg/Kg
# 1    Fracciones de Hidrocarburos F3 (C28-C40)            mg/Kg
# 2       Fracción de Hidrocarburos F1 (C5-C10)            mg/Kg
# 3  Hidrocarburos totales de petróleo (C5-C40)            mg/Kg
# 4    Fracciones de Hidrocarburos F2 (C10-C28)            mg/Kg
#
# [5 rows x 22 columns]

# %%
#Componente agua
#URL de exportación: https://docs.google.com/spreadsheets/d/1sf285A4XFBtwktd6E2X1ZmDnr1OJaTv6/edit?usp=drive_link&ouid=110342148515634196231&rtpof=true&sd=true
URL_AGUA = 'https://docs.google.com/spreadsheets/d/1sf285A4XFBtwktd6E2X1ZmDnr1OJaTv6/export?format=xlsx'
agua = pd.read_excel(URL_AGUA)
agua.head()
# Out:
#                       Número de informe  \
# 0  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 1  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 2  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 3  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 4  INFORME N° 00055-2019-OEFA/DEAM-SSIM
#
#                              Nombre de la Evaluación              Etapa  \
# 0  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 1  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 2  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 3  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 4  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
#
#   Componente ambiental Procedencia de la Muestra  \
# 0                 Agua  Agua natural superficial
# 1                 Agua  Agua natural superficial
# 2                 Agua  Agua natural superficial
# 3                 Agua  Agua natural superficial
# 4                 Agua  Agua natural superficial
#
#   Procedencia Especifica de la Muestra Nombre del punto    Este    Norte  \
# 0              Agua superficial de río      F01861-AG01  601347  9506175
# 1              Agua superficial de río      F01861-AG01  601347  9506175
# 2              Agua superficial de río      F01861-AG01  601347  9506175
# 3              Agua superficial de río      F01861-AG01  601347  9506175
# 4              Agua superficial de río      F01861-AG01  601347  9506175
#
#    Altitud  Zona  Datum                           Descripción de ubicación  \
# 0       76    18  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
# 1       76    18  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
# 2       76    18  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
# 3       76    18  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
# 4       76    18  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
#
#   Tipo de muestra                  Tipo de análisis    Fecha        Hora  \
# 0          Simple                   Fisico Químicos  1/14/19  5:54:00 PM
# 1          Simple  Aniones por Cromatografía Iónica  1/14/19  5:54:00 PM
# 2          Simple   Ensayo por cromatografía - PAHS  1/14/19  5:54:00 PM
# 3          Simple   Ensayo por cromatografía - PAHS  1/14/19  5:54:00 PM
# 4          Simple   Ensayo por cromatografía - PAHS  1/14/19  5:54:00 PM
#
#        Valor         Parámetro Unidad de medida
# 0     <0.100  Aceites y grasas             mg/L
# 1      0,233          Cloruros             mg/L
# 2  <0.000013        Acenafteno             mg/L
# 3  <0.000013      Acenaftileno             mg/L
# 4  <0.000016         Antraceno             mg/L

# %%
#Componente sedimento
#URL de exportación: https://docs.google.com/spreadsheets/d/1QguQUQ66N5LRcYsGiQuEwuIf9XOrxTbF/edit?usp=drive_link&ouid=110342148515634196231&rtpof=true&sd=true
import warnings
warnings.filterwarnings('ignore')
URL_SEDIMENTO = 'https://docs.google.com/spreadsheets/d/1QguQUQ66N5LRcYsGiQuEwuIf9XOrxTbF/export?format=xlsx'
sedimento = pd.read_excel(URL_SEDIMENTO)
sedimento.head()
# Out:
#                       Número de informe  \
# 0  INFORME N° 00580-2019-OEFA/DEAM-SSIM
# 1  INFORME N° 00580-2019-OEFA/DEAM-SSIM
# 2  INFORME N° 00580-2019-OEFA/DEAM-SSIM
# 3  INFORME N° 00580-2019-OEFA/DEAM-SSIM
# 4  INFORME N° 00580-2019-OEFA/DEAM-SSIM
#
#                              Nombre de la Evaluación             Etapa  \
# 0  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
# 1  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
# 2  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
# 3  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
# 4  Identificación de Pasivo Ambiental del Subsect...  Primer monitoreo
#
#   Componente ambiental Procedencia de la Muestra  \
# 0            Sedimento     Sedimento continental
# 1            Sedimento     Sedimento continental
# 2            Sedimento     Sedimento continental
# 3            Sedimento     Sedimento continental
# 4            Sedimento     Sedimento continental
#
#   Procedencia Especifica de la Muestra Nombre del punto    Este    Norte  \
# 0            Área de potencial interés      F05898_SD01  468461  9507737
# 1            Área de potencial interés      F05898_SD01  468461  9507737
# 2            Área de potencial interés      F05898_SD01  468461  9507737
# 3            Área de potencial interés      F05898_SD01  468461  9507737
# 4            Área de potencial interés      F05898_SD01  468461  9507737
#
#    Altitud  ...   Datum                           Descripción de ubicación  \
# 0        0  ...  WGS 84  Muestra puntual de sedimentos tomada a 4m en d...
# 1        0  ...  WGS 84  Muestra puntual de sedimentos tomada a 4m en d...
# 2        0  ...  WGS 84  Muestra puntual de sedimentos tomada a 4m en d...
# 3        0  ...  WGS 84  Muestra puntual de sedimentos tomada a 4m en d...
# 4        0  ...  WGS 84  Muestra puntual de sedimentos tomada a 4m en d...
#
#   Tipo de muestra                 Tipo de análisis  \
# 0          Simple   Ensayo por cromatografía - HTP
# 1          Simple   Ensayo por cromatografía - HTP
# 2          Simple   Ensayo por cromatografía - HTP
# 3          Simple  Ensayo por cromatografía - PAHS
# 4          Simple  Ensayo por cromatografía - PAHS
#
#   Etapa de extracción secuencial    Fecha      Hora    Valor  \
# 0                      No aplica  10/6/19  10:07:00     <1.9
# 1                      No aplica  10/6/19  10:07:00     <6.8
# 2                      No aplica  10/6/19  10:07:00     <6.8
# 3                      No aplica  10/6/19  10:07:00  <0.0054
# 4                      No aplica  10/6/19  10:07:00  <0.0054
#
#                                   Parámetro Unidad de medida
# 0   Fracciones de Hidrocarburos F1 (C6-C10)            mg/Kg
# 1  Fracciones de Hidrocarburos F2 (C10-C28)            mg/Kg
# 2  Fracciones de Hidrocarburos F3 (C28-C40)            mg/Kg
# 3                                Acenafteno            mg/Kg
# 4                              Acenaftileno            mg/Kg
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Carga de Normativas Ambientales
#
# Para la evaluación del cumplimiento ambiental en las distintas matrices de estudio (agua, suelo y sedimentos) se consideraron normativas vigentes tanto en Perú como en Argentina.
# En el caso de **Perú**, se trabajó con los *Estándares de Calidad Ambiental* (ECA) para agua y suelo (Decretos Supremos N° 004-2017-MINAM y N° 011-2017-MINAM, respectivamente), así como con los *Límites Máximos Permisibles* (LMP) aplicables a efluentes líquidos.
#
# Para **Argentina**, la normativa ambiental utilizada como referencia (Ley Nacional de Residuos Peligrosos N°24.051 y su Decreto Reglamentario N°831/93), no establece límites de calidad explícitos por matriz de la misma manera que los ECA en Perú. Sin embargo, presenta criterios para la identificación y gestión de residuos peligrosos, incluyendo concentraciones de referencia para ciertos contaminantes.
# Dado que estos valores no constituyen estándares de calidad ambiental directamente comparables, en el presente trabajo se emprlean como referencia complementaria, junto con criterios técnico-interpretativos y valores guía utilizados en la práctica, a fin de evaluar el grado de contaminación y permitir una comparación entre ambos marcos regulatorios.
#
# - Normativa para Suelo (Perú): https://sinia.minam.gob.pe/normas/aprueban-estandares-calidad-ambiental-eca-suelo
#
# - Normativa para Agua (Perú): https://www.minam.gob.pe/wp-content/uploads/2017/06/DS-004-2017-MINAM.pdf
#
# - Límites Máximos Permisibles (Perú): https://sinia.minam.gob.pe/normas/limites-maximos-permisibles-lmp-efluentes-liquidos-sub-sector
#
# - Normativa para Suelo (Decreto 831/93, Tabla 9, Argentina):https://servicios.infoleg.gob.ar/infolegInternet/anexos/10000-14999/12830/norma.htm
#
# - Normativa para Agua (Decreto 831/93, Tabla 5, Argentina): https://servicios.infoleg.gob.ar/infolegInternet/anexos/10000-14999/12830/norma.htm

# %%
# Normativas Perú
#URL de exportación: https://docs.google.com/spreadsheets/d/16_k1zxeZNGY96GGzMfrbVDdiSNciSNk-/edit?usp=drive_link&ouid=110342148515634196231&rtpof=true&sd=true
URL_NORM_PERU = 'https://docs.google.com/spreadsheets/d/16_k1zxeZNGY96GGzMfrbVDdiSNciSNk-/export?format=xlsx'
norm_peru = pd.read_excel(URL_NORM_PERU)
norm_peru.head(22)
# Out:
#    matriz descripción                          parametro unidad    valor   \
# 0   Suelo        BTEX                            Benceno  mg/kg     0.030
# 1   Suelo        BTEX                            Tolueno  mg/kg     0.370
# 2   Suelo        BTEX                        Etilbenceno  mg/kg     0.082
# 3   Suelo        BTEX                            Xilenos  mg/kg    11.000
# 4   Suelo         PAH                          Naftaleno  mg/kg     0.600
# 5   Suelo         PAH                     Benzo(a)pireno  mg/kg     0.700
# 6   Suelo         HTP                        F1 (C6-C10)  mg/kg   200.000
# 7   Suelo         HTP                      F2 (>C10-C28)  mg/kg  1200.000
# 8   Suelo         HTP                      F3 (>C28-C40)  mg/kg  3000.000
# 9   Suelo    Orgánico                                PCB  mg/kg     1.300
# 10  Suelo    Orgánico                  Tetracloroetileno  mg/kg     0.200
# 11  Suelo    Orgánico                    Tricloroetileno  mg/kg     0.010
# 12  Suelo     Metales                           Arsénico  mg/kg    50.000
# 13  Suelo     Metales                              Bario  mg/kg   500.000
# 14  Suelo     Metales                             Cadmio  mg/kg    10.000
# 15  Suelo     Metales                        Cromo total  mg/kg  1000.000
# 16  Suelo     Metales                           Cromo VI  mg/kg     0.400
# 17  Suelo     Metales                           Mercurio  mg/kg     6.600
# 18  Suelo     Metales                              Plomo  mg/kg   140.000
# 19  Suelo     Metales                      Cianuro libre  mg/kg     0.900
# 20   Agua         HTP  Hidrocarburos Totales de Petróleo   mg/L     0.010
# 21   Agua        BTEX                            Benceno   mg/L     0.010
#
#                 norma
# 0   DS 011-2017-MINAM
# 1   DS 011-2017-MINAM
# 2   DS 011-2017-MINAM
# 3   DS 011-2017-MINAM
# 4   DS 011-2017-MINAM
# 5   DS 011-2017-MINAM
# 6   DS 011-2017-MINAM
# 7   DS 011-2017-MINAM
# 8   DS 011-2017-MINAM
# 9   DS 011-2017-MINAM
# 10  DS 011-2017-MINAM
# 11  DS 011-2017-MINAM
# 12  DS 011-2017-MINAM
# 13  DS 011-2017-MINAM
# 14  DS 011-2017-MINAM
# 15  DS 011-2017-MINAM
# 16  DS 011-2017-MINAM
# 17  DS 011-2017-MINAM
# 18  DS 011-2017-MINAM
# 19  DS 011-2017-MINAM
# 20  DS 004-2017-MINAM
# 21  DS 004-2017-MINAM

# %%
# Normativas Argentina
# URL de exportación: https://docs.google.com/spreadsheets/d/1tj6sqxXjmq_hBnYca8EnNQtYZvD9P05G/edit?usp=drive_link&ouid=110342148515634196231&rtpof=true&sd=true
URL_NORM_ARG = 'https://docs.google.com/spreadsheets/d/1tj6sqxXjmq_hBnYca8EnNQtYZvD9P05G/export?format=xlsx'
norm_arg = pd.read_excel(URL_NORM_ARG)
norm_arg.head(22)
# Out:
#    matriz descripción        parametro unidad   valor  \
# 0   suelo        BTEX          Benceno   µg/g     5.0
# 1   suelo        BTEX      Etilbenceno   µg/g    50.0
# 2   suelo        BTEX          Tolueno   µg/g    30.0
# 3   suelo        BTEX  Xilenos totales   µg/g    50.0
# 4   suelo         HTP        HTP total  mg/kg  1000.0
# 5   suelo     metales            Plomo   µg/g  1000.0
# 6   suelo     metales         Arsenico   µg/g    50.0
# 7   suelo     metales            Bario   µg/g  2000.0
# 8   suelo     metales          Berilio   µg/g     8.0
# 9   suelo     metales           Cadmio   µg/g    20.0
# 10  suelo     metales             Zinc   µg/g  1500.0
# 11  suelo     metales          Cobalto   µg/g   300.0
# 12  suelo     metales            Cobre   µg/g   500.0
# 13  suelo     metales            Cromo   µg/g   800.0
# 14  suelo     metales         Mercurio   µg/g    20.0
# 15  suelo     metales        Molibdeno   µg/g    40.0
# 16  suelo     metales           Niquel   µg/g   500.0
# 17  suelo     metales            Plata   µg/g    40.0
# 18  suelo     metales          Selenio   µg/g    10.0
# 19  suelo         PAH        PAH total  mg/kg    10.0
# 20   agua     Metales         Arsenico   µg/L   100.0
# 21   agua     Metales           Cadmio   µg/L    10.0
#
#                                                 norma
# 0   Decreto 831 (Niveles Guía de Calidad de Suelos...
# 1   Decreto 831 (Niveles Guía de Calidad de Suelos...
# 2   Decreto 831 (Niveles Guía de Calidad de Suelos...
# 3   Decreto 831 (Niveles Guía de Calidad de Suelos...
# 4            Referencia de Calidad de Suelo (General)
# 5   Decreto 831 (Niveles Guía de Calidad de Suelos...
# 6   Decreto 831 (Niveles Guía de Calidad de Suelos...
# 7   Decreto 831 (Niveles Guía de Calidad de Suelos...
# 8   Decreto 831 (Niveles Guía de Calidad de Suelos...
# 9   Decreto 831 (Niveles Guía de Calidad de Suelos...
# 10  Decreto 831 (Niveles Guía de Calidad de Suelos...
# 11  Decreto 831 (Niveles Guía de Calidad de Suelos...
# 12  Decreto 831 (Niveles Guía de Calidad de Suelos...
# 13  Decreto 831 (Niveles Guía de Calidad de Suelos...
# 14  Decreto 831 (Niveles Guía de Calidad de Suelos...
# 15  Decreto 831 (Niveles Guía de Calidad de Suelos...
# 16  Decreto 831 (Niveles Guía de Calidad de Suelos...
# 17  Decreto 831 (Niveles Guía de Calidad de Suelos...
# 18  Decreto 831 (Niveles Guía de Calidad de Suelos...
# 19                                 Guia Internacional
# 20                   Decreto 831 (Agua de Irrigación)
# 21                   Decreto 831 (Agua de Irrigación)

# %% [markdown]
# ## Etapas adicionales intermedias para la limpieza de datos

# %%
#Segundo: limpiamos los valores y lo reemplazamos por LD/2
import re
def limpiar_valor(v):
  '''
  Convierte un valor analítico a numero_
  - Si contiene '<', extra el LD y lo divide entre 2 (convención USEPA)
  - Reemplaza coma decimal por punto
  - Si no puede convertirse, devuelve NaN
  '''

  v = str(v).strip()
  v = v.replace(',','.')     #linea para cambiar la coma decimal por el punto
  if v.startswith('<'):
    try:
      lod = float(v.replace('<', '').strip())   #linea para extraer el número despues del '<'
      return lod/2
    except ValueError:
      return np.nan
  try:
    return float(v)
  except ValueError:
    return np.nan

#Tercero: aplicar la función a toda la columna Valor de cada dataset
suelo['Valor_num'] = suelo['Valor'].apply(limpiar_valor)

#Cuarto: imprimir resultado
print('Columna Valor_num creada')
print(f'Valores numéricos válidos (suelo): {suelo['Valor_num'].notna().sum}')
print(f'Valores no convertibles (NaN) (suelo): {suelo['Valor_num'].isna().sum}')
# Out:
# Columna Valor_num creada
# Valores numéricos válidos (suelo): <bound method Series.sum of 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 994    True
# 995    True
# 996    True
# 997    True
# 998    True
# Name: Valor_num, Length: 999, dtype: bool>
# Valores no convertibles (NaN) (suelo): <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 994    False
# 995    False
# 996    False
# 997    False
# 998    False
# Name: Valor_num, Length: 999, dtype: bool>

# %%
agua['Valor_num'] = agua['Valor'].apply(limpiar_valor)
print(f'Valores numéricos válidos (agua): {agua['Valor_num'].notna().sum}')
print(f'Valores no convertibles (NaN) (agua): {agua['Valor_num'].isna().sum}')
# Out:
# Valores numéricos válidos (agua): <bound method Series.sum of 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 993    True
# 994    True
# 995    True
# 996    True
# 997    True
# Name: Valor_num, Length: 998, dtype: bool>
# Valores no convertibles (NaN) (agua): <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 993    False
# 994    False
# 995    False
# 996    False
# 997    False
# Name: Valor_num, Length: 998, dtype: bool>

# %%
sedimento['Valor_num'] = sedimento['Valor'].apply(limpiar_valor)
print(f'Valores numéricos válidos (sedimento): {sedimento['Valor_num'].notna().sum}')
print(f'Valores no convertibles (NaN) (sedimento): {sedimento['Valor_num'].isna().sum}')
# Out:
# Valores numéricos válidos (sedimento): <bound method Series.sum of 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 213    True
# 214    True
# 215    True
# 216    True
# 217    True
# Name: Valor_num, Length: 218, dtype: bool>
# Valores no convertibles (NaN) (sedimento): <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 213    False
# 214    False
# 215    False
# 216    False
# 217    False
# Name: Valor_num, Length: 218, dtype: bool>

# %%
# Quinto: Comparar el correcto agregado de la columna
sedimento[['Parámetro', 'Valor', 'Valor_num', 'Unidad de medida']].head(10)

# Quedó el comando con sedimento pero corroboré con los 3 dataset
# Out:
#                                   Parámetro    Valor  Valor_num  \
# 0   Fracciones de Hidrocarburos F1 (C6-C10)     <1.9     0.9500
# 1  Fracciones de Hidrocarburos F2 (C10-C28)     <6.8     3.4000
# 2  Fracciones de Hidrocarburos F3 (C28-C40)     <6.8     3.4000
# 3                                Acenafteno  <0.0054     0.0027
# 4                              Acenaftileno  <0.0054     0.0027
# 5                                 Antraceno  <0.0054     0.0027
# 6                       Benzo (a) Antraceno  <0.0054     0.0027
# 7                          Benzo (a) Pireno  <0.0054     0.0027
# 8                     Benzo (b) Fluoranteno  <0.0054     0.0027
# 9                    Benzo (g,h,i) Perileno  <0.0054     0.0027
#
#   Unidad de medida
# 0            mg/Kg
# 1            mg/Kg
# 2            mg/Kg
# 3            mg/Kg
# 4            mg/Kg
# 5            mg/Kg
# 6            mg/Kg
# 7            mg/Kg
# 8            mg/Kg
# 9            mg/Kg

# %%
agua[['Parámetro', 'Valor', 'Valor_num', 'Unidad de medida']].head(5)
# Out:
#           Parámetro      Valor  Valor_num Unidad de medida
# 0  Aceites y grasas     <0.100   0.050000             mg/L
# 1          Cloruros      0,233   0.233000             mg/L
# 2        Acenafteno  <0.000013   0.000006             mg/L
# 3      Acenaftileno  <0.000013   0.000006             mg/L
# 4         Antraceno  <0.000016   0.000008             mg/L

# %%
sedimento[['Parámetro', 'Valor', 'Valor_num', 'Unidad de medida']].head(5)
# Out:
#                                   Parámetro    Valor  Valor_num  \
# 0   Fracciones de Hidrocarburos F1 (C6-C10)     <1.9     0.9500
# 1  Fracciones de Hidrocarburos F2 (C10-C28)     <6.8     3.4000
# 2  Fracciones de Hidrocarburos F3 (C28-C40)     <6.8     3.4000
# 3                                Acenafteno  <0.0054     0.0027
# 4                              Acenaftileno  <0.0054     0.0027
#
#   Unidad de medida
# 0            mg/Kg
# 1            mg/Kg
# 2            mg/Kg
# 3            mg/Kg
# 4            mg/Kg

# %%
suelo[['Parámetro', 'Valor', 'Valor_num', 'Unidad de medida']].head(5)
# Out:
#                                     Parámetro  Valor  Valor_num  \
# 0    Fracciones de Hidrocarburos F2 (C10-C28)    514     514.00
# 1    Fracciones de Hidrocarburos F3 (C28-C40)   3795    3795.00
# 2       Fracción de Hidrocarburos F1 (C5-C10)   <0.3       0.15
# 3  Hidrocarburos totales de petróleo (C5-C40)   4310    4310.00
# 4    Fracciones de Hidrocarburos F2 (C10-C28)  <5.00       2.50
#
#   Unidad de medida
# 0            mg/Kg
# 1            mg/Kg
# 2            mg/Kg
# 3            mg/Kg
# 4            mg/Kg

# %% [markdown]
# # 5. Exploración Normativa
#
# *   Asignación de valores de referencia
# *   Comparación de datos con Normativa Perú
# *   Comparación de datos con Normativa Argentina
# *   Cálculo de excedencias
# *   Porcentaje de superación por parámetro y matriz

# %% [markdown]
# ## Notas:
# - Eliminar datos de Agua que no tengan unidades en mg/L
# - Datos de Suelo comparables con Normativa Peruana sin ediciones
# - Modificar datos de Suelo para comparar con Normativa Argentina en µg/g y µg/L
# - Utilizar columnas de Valor_num

# %%
# Datos de Agua inválidos. Son de medición de temperatura, pH y conductividad.
# No se incluye contaminantes.

agua_contaminantes = agua[agua['Unidad de medida'] == 'mg/L']
agua_contaminantes.head()

# Suelo no tiene datos inválidos según Normativa Peruana.
# Out:
#                       Número de informe  \
# 0  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 1  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 2  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 3  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 4  INFORME N° 00055-2019-OEFA/DEAM-SSIM
#
#                              Nombre de la Evaluación              Etapa  \
# 0  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 1  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 2  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 3  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 4  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
#
#   Componente ambiental Procedencia de la Muestra  \
# 0                 Agua  Agua natural superficial
# 1                 Agua  Agua natural superficial
# 2                 Agua  Agua natural superficial
# 3                 Agua  Agua natural superficial
# 4                 Agua  Agua natural superficial
#
#   Procedencia Especifica de la Muestra Nombre del punto    Este    Norte  \
# 0              Agua superficial de río      F01861-AG01  601347  9506175
# 1              Agua superficial de río      F01861-AG01  601347  9506175
# 2              Agua superficial de río      F01861-AG01  601347  9506175
# 3              Agua superficial de río      F01861-AG01  601347  9506175
# 4              Agua superficial de río      F01861-AG01  601347  9506175
#
#    Altitud  ...  Datum                           Descripción de ubicación  \
# 0       76  ...  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
# 1       76  ...  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
# 2       76  ...  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
# 3       76  ...  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
# 4       76  ...  WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
#
#   Tipo de muestra                  Tipo de análisis    Fecha        Hora  \
# 0          Simple                   Fisico Químicos  1/14/19  5:54:00 PM
# 1          Simple  Aniones por Cromatografía Iónica  1/14/19  5:54:00 PM
# 2          Simple   Ensayo por cromatografía - PAHS  1/14/19  5:54:00 PM
# 3          Simple   Ensayo por cromatografía - PAHS  1/14/19  5:54:00 PM
# 4          Simple   Ensayo por cromatografía - PAHS  1/14/19  5:54:00 PM
#
#        Valor         Parámetro Unidad de medida Valor_num
# 0     <0.100  Aceites y grasas             mg/L  0.050000
# 1      0,233          Cloruros             mg/L  0.233000
# 2  <0.000013        Acenafteno             mg/L  0.000006
# 3  <0.000013      Acenaftileno             mg/L  0.000006
# 4  <0.000016         Antraceno             mg/L  0.000008
#
# [5 rows x 21 columns]

# %%
# Datos de pH de Agua (SOLO NORMATIVA PERUANA)
# ADICIONAL

agua_ph = agua [agua['Unidad de medida'] == 'Unidad de pH']
agua_ph.head()
# Out:
#                         Número de informe  \
# 156  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 160  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 164  INFORME N° 00055-2019-OEFA/DEAM-SSIM
# 170  INFORME N° 00580-2019-OEFA/DEAM-SSIM
# 211  INFORME N° 00580-2019-OEFA/DEAM-SSIM
#
#                                Nombre de la Evaluación              Etapa  \
# 156  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 160  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 164  Identificación de Pasivo Ambiental del Subsect...  Segundo monitoreo
# 170  Identificación de Pasivo Ambiental del Subsect...   Primer monitoreo
# 211  Identificación de Pasivo Ambiental del Subsect...   Primer monitoreo
#
#     Componente ambiental Procedencia de la Muestra  \
# 156                 Agua  Agua natural superficial
# 160                 Agua  Agua natural superficial
# 164                 Agua  Agua natural superficial
# 170                 Agua               Agua salina
# 211                 Agua               Agua salina
#
#     Procedencia Especifica de la Muestra Nombre del punto    Este    Norte  \
# 156              Agua superficial de río      F01861-AG01  601347  9506175
# 160              Agua superficial de río      F01861-AG02  601300  9506293
# 164              Agua superficial de río      F01861-AG03  601399  9506003
# 170                          Agua de mar      F05898_AG01  468461  9507737
# 211                          Agua de mar      F05898_AG02  468462  9507741
#
#      Altitud  ...   Datum                           Descripción de ubicación  \
# 156       76  ...   WGS84  Punto ubicado en el río Tigre a 9 m de la oril...
# 160       76  ...   WGS84  Punto ubicado en el río Tigre a 15 m de la ori...
# 164       76  ...   WGS84  Punto ubicado en el río Tigre a 20 m de la ori...
# 170        0  ...  WGS 84  Muestra puntual de agua de mar tomada a 4m en ...
# 211        0  ...  WGS 84  Muestra puntual de agua de mar tomada a 6m en ...
#
#     Tipo de muestra     Tipo de análisis      Fecha        Hora Valor  \
# 156          Simple    Resultado in situ    1/14/19  5:54:00 PM  6,26
# 160          Simple    Resultado in situ    1/14/19  5:27:00 PM  6,23
# 164          Simple    Resultado in situ    1/14/19  6:19:00 PM  6,41
# 170          Simple  Restultados in situ  6/10/2019  8:59:00 AM   7,8
# 211          Simple  Restultados in situ  6/10/2019  9:21:00 AM  7,83
#
#                   Parámetro Unidad de medida Valor_num
# 156  Potencial de hidrógeno     Unidad de pH      6.26
# 160  Potencial de hidrógeno     Unidad de pH      6.23
# 164  Potencial de hidrógeno     Unidad de pH      6.41
# 170  Potencial de hidrógeno     Unidad de pH      7.80
# 211  Potencial de hidrógeno     Unidad de pH      7.83
#
# [5 rows x 21 columns]

# %%
# Suelo
# µg/g es equivalente a mg/kg --> No es necesario modificar Valor_num
# Añadir columna 'Unidad de medida_arg' para comparación con Normativa Argentina

suelo['Unidad de medida_arg'] = 'µg/g'

suelo[['Parámetro', 'Valor', 'Valor_num', 'Unidad de medida','Unidad de medida_arg']].head(5)
# Out:
#                                     Parámetro  Valor  Valor_num  \
# 0    Fracciones de Hidrocarburos F2 (C10-C28)    514     514.00
# 1    Fracciones de Hidrocarburos F3 (C28-C40)   3795    3795.00
# 2       Fracción de Hidrocarburos F1 (C5-C10)   <0.3       0.15
# 3  Hidrocarburos totales de petróleo (C5-C40)   4310    4310.00
# 4    Fracciones de Hidrocarburos F2 (C10-C28)  <5.00       2.50
#
#   Unidad de medida Unidad de medida_arg
# 0            mg/Kg                 µg/g
# 1            mg/Kg                 µg/g
# 2            mg/Kg                 µg/g
# 3            mg/Kg                 µg/g
# 4            mg/Kg                 µg/g

# %%
# Agua
# Crear nueva columna de Valor_num_arg para comparación con Normativa Argentina
# µg/L --> mg/L * 1000
# Añadir columna 'Unidad de medida_arg' para comparación con Normativa Argentina

# 1ero NO asumir conversión (mg/L se mantiene)
agua_contaminantes['Valor_num_arg'] = agua_contaminantes['Valor_num']
agua_contaminantes['Unidad de medida_arg'] = agua_contaminantes['Unidad de medida']

# 2do Parámetros que NO se convierten (mg/L se mantienen)
exclude_params = ['Aceites y grasas', 'Cloruros', 'PAH total', 'HTP total']

agua[['Parámetro', 'Valor', 'Valor_num','Valor_num_arg', 'Unidad de medida','Unidad de medida_arg']].head(5)

# %%
# Agua
# Crear nueva columna de Valor_num_arg para comparación con Normativa Argentina
# µg/L --> mg/L * 1000
# Añadir columna 'Unidad de medida_arg' para comparación con Normativa Argentina

agua_contaminantes['Valor_num_arg'] = agua_contaminantes['Valor_num'] * 1000
agua_contaminantes['Unidad de medida_arg'] = 'µg/L'

agua[['Parámetro', 'Valor', 'Valor_num','Valor_num_arg', 'Unidad de medida','Unidad de medida_arg']].head(5)

# %%
# Initialize 'Valor_num_arg' and 'Unidad de medida_arg' columns for agua_contaminantes
# By default, assume no conversion (mg/L remains mg/L)
agua_contaminantes['Valor_num_arg'] = agua_contaminantes['Valor_num']
agua_contaminantes['Unidad de medida_arg'] = agua_contaminantes['Unidad de medida']

# Define parameters that should NOT be converted (they stay in mg/L)
# In this specific case, the prompt implies all 'mg/L' values except certain ones should be converted
# The previous implementation already handled this more robustly.
# For this cell, I will implement the direct condition as requested: convert if 'Unidad de medida' is 'mg/L'

# 2do Parámetros que NO se convierten (mg/L se mantienen)
exclude_params = ['Aceites y grasas', 'Cloruros', 'PAH total', 'HTP total']

# Create a boolean mask for rows where 'Unidad de medida' is 'mg/L'
conversion_mask = agua_contaminantes['Unidad de medida'] == 'mg/L'

# Apply conversion (mg/L to µg/L) for the selected rows
agua_contaminantes.loc[conversion_mask, 'Valor_num_arg'] = agua_contaminantes.loc[conversion_mask, 'Valor_num'] * 1000
agua_contaminantes.loc[conversion_mask, 'Unidad de medida_arg'] = 'µg/L'


agua_contaminantes[['Parámetro', 'Valor', 'Valor_num','Valor_num_arg', 'Unidad de medida','Unidad de medida_arg']].head(5)

# %% [markdown]
# ## FALTA TERMINAR CONVERSIÓN DE UNIDADES PARA AGUA.

# %% [markdown]
# ## 5.1 Comparación para SUELOS

# %%
import pandas as pd
import numpy as np

# ============================================================
# 5.1a Comparación de SUELO con la Normativa Peruana (ECA Suelo)
# ============================================================

# Filtramos la normativa a la matriz "Suelo"
norm_peru_suelo = norm_peru[norm_peru['matriz'].str.lower() == 'suelo'].copy()

# Strip whitespace from column names to prevent potential KeyError due to hidden characters
norm_peru_suelo.columns = norm_peru_suelo.columns.str.strip()

# Diccionario de correspondencia: nombre del parámetro en IPASH -> nombre en la normativa
# (los nombres no son idénticos entre bases: distinto uso de tildes, mayúsculas,
#  paréntesis y nomenclatura de fracciones de hidrocarburos)
mapa_peru = {
    'Arsénico':                                 'Arsénico',
    'Bario':                                     'Bario',
    'Cadmio':                                    'Cadmio',
    'Cromo Total':                               'Cromo total',
    'Mercurio':                                  'Mercurio',
    'Plomo':                                      'Plomo',
    'Naftaleno':                                 'Naftaleno',
    'Benzo (a) Pireno':                          'Benzo(a)pireno',
    'Fracciones de Hidrocarburos F1 (C6-C10)':   'F1 (C6-C10)',
    'Fracciones de Hidrocarburos F2 (C10-C28)':  'F2 (>C10-C28)',
    'Fracciones de Hidrocarburos F3 (C28-C40)':  'F3 (>C28-C40)',
}
# Nota: BTEX (Benceno, Tolueno, Etilbenceno, Xilenos), PCB, Cromo VI, Cianuro libre,
# Tetracloroetileno y Tricloroetileno no fueron analizados en la base IPASH de suelo,
# por lo que no tienen comparación posible con esta normativa.

limite_peru = norm_peru_suelo.set_index('parametro')['valor'].to_dict()

suelo['parametro_norma_peru'] = suelo['Parámetro'].map(mapa_peru)
suelo['limite_peru']          = suelo['parametro_norma_peru'].map(limite_peru)
suelo['supera_peru']          = suelo['Valor_num'] > suelo['limite_peru']

print(f"Parámetros comparables con la Normativa Peruana: {suelo['limite_peru'].notna().sum()} registros")
print(f"Registros que superan el ECA Suelo (Perú): {int(suelo['supera_peru'].sum())}")
suelo.loc[suelo['limite_peru'].notna(), ['Parámetro','Valor_num','limite_peru','supera_peru']].head(10)
# Out:
# Parámetros comparables con la Normativa Peruana: 566 registros
# Registros que superan el ECA Suelo (Perú): 232
#                                    Parámetro  Valor_num  limite_peru  \
# 0   Fracciones de Hidrocarburos F2 (C10-C28)      514.0       1200.0
# 1   Fracciones de Hidrocarburos F3 (C28-C40)     3795.0       3000.0
# 4   Fracciones de Hidrocarburos F2 (C10-C28)        2.5       1200.0
# 5   Fracciones de Hidrocarburos F3 (C28-C40)        2.5       3000.0
# 8   Fracciones de Hidrocarburos F2 (C10-C28)     2389.0       1200.0
# 9   Fracciones de Hidrocarburos F3 (C28-C40)     4039.0       3000.0
# 12  Fracciones de Hidrocarburos F2 (C10-C28)      217.0       1200.0
# 13  Fracciones de Hidrocarburos F3 (C28-C40)      406.0       3000.0
# 16  Fracciones de Hidrocarburos F2 (C10-C28)    17866.0       1200.0
# 17  Fracciones de Hidrocarburos F3 (C28-C40)    19066.0       3000.0
#
#     supera_peru
# 0         False
# 1          True
# 4         False
# 5         False
# 8          True
# 9          True
# 12        False
# 13        False
# 16         True
# 17         True

# %%
# ================================================================
# 5.1b Comparación de SUELO con la Normativa Argentina (Decreto 831)
# ================================================================

norm_arg_suelo = norm_arg[norm_arg['matriz'].str.lower() == 'suelo'].copy()

mapa_arg = {
    'Arsénico':    'Arsenico',
    'Bario':        'Bario',
    'Berilio':      'Berilio',
    'Cadmio':       'Cadmio',
    'Zinc':         'Zinc',
    'Cobalto':      'Cobalto',
    'Cobre':        'Cobre',
    'Cromo Total':  'Cromo',
    'Mercurio':     'Mercurio',
    'Molibdeno':    'Molibdeno',
    'Níquel':       'Niquel',
    'Plata':        'Plata',
    'Plomo':        'Plomo',
    'Selenio':      'Selenio',
    'Hidrocarburos totales de petróleo (C10-C40)': 'HTP total',
    'Hidrocarburos totales de petróleo (C5-C40)':  'HTP total',
}
# Nota: BTEX no fue analizado en la base IPASH de suelo. El "PAH total" de la
# normativa argentina se calcula aparte (celda siguiente), ya que corresponde
# a la SUMA de los 16 HAP prioritarios, no a un parámetro medido de forma directa.

limite_arg = norm_arg_suelo.set_index('parametro')['valor'].to_dict()

suelo['parametro_norma_arg'] = suelo['Parámetro'].map(mapa_arg)
suelo['limite_arg']          = suelo['parametro_norma_arg'].map(limite_arg)
# suelo['Valor_num_arg'] ya está en µg/g == mg/kg (celda de conversión de unidades), sin factor de conversión
suelo['supera_arg']          = suelo['Valor_num'] > suelo['limite_arg']

print(f"Parámetros comparables con la Normativa Argentina: {suelo['limite_arg'].notna().sum()} registros")
print(f"Registros que superan el nivel guía (Argentina): {int(suelo['supera_arg'].sum())}")
suelo.loc[suelo['limite_arg'].notna(), ['Parámetro','Valor_num','limite_arg','supera_arg']].head(10)
# Out:
# Parámetros comparables con la Normativa Argentina: 212 registros
# Registros que superan el nivel guía (Argentina): 15
#                                      Parámetro  Valor_num  limite_arg  \
# 3   Hidrocarburos totales de petróleo (C5-C40)    4310.00      1000.0
# 7   Hidrocarburos totales de petróleo (C5-C40)       2.50      1000.0
# 11  Hidrocarburos totales de petróleo (C5-C40)    6428.00      1000.0
# 15  Hidrocarburos totales de petróleo (C5-C40)     622.00      1000.0
# 19  Hidrocarburos totales de petróleo (C5-C40)   36932.00      1000.0
# 23  Hidrocarburos totales de petróleo (C5-C40)    2821.00      1000.0
# 43                                       Plata       1.50        40.0
# 45                                    Arsénico       8.75        50.0
# 46                                       Bario     133.80      2000.0
# 47                                     Berilio       0.75         8.0
#
#     supera_arg
# 3         True
# 7        False
# 11        True
# 15       False
# 19        True
# 23        True
# 43       False
# 45       False
# 46       False
# 47       False

# %%
# ---------------------------------------------------------------------------
# 5.1c HAP total (Argentina): la normativa regula la SUMA de los 16 HAP
#      prioritarios (EPA-16), no cada uno por separado. Se calcula la suma
#      por punto/fecha de muestreo y se compara contra el límite "PAH total".
# ---------------------------------------------------------------------------

pahs_16 = ['Acenafteno','Acenaftileno','Antraceno','Benzo (a) Antraceno','Benzo (a) Pireno',
           'Benzo (b) Fluoranteno','Benzo (g,h,i) Perileno','Benzo (k) Fluoranteno','Criseno',
           'Dibenzo (a,h) Antraceno','Fenantreno','Fluoranteno','Fluoreno',
           'Indeno (1,2,3 cd) Pireno','Naftaleno','Pireno']

id_muestra = ['Número de informe','Nombre del punto','Fecha','Hora','Este','Norte','Zona']

pah_total = (suelo[suelo['Parámetro'].isin(pahs_16)]
             .groupby(id_muestra)['Valor_num'].sum()
             .reset_index()
             .rename(columns={'Valor_num': 'Valor_num_arg'}))
pah_total['Parámetro']  = 'HAP total (calculado)'
pah_total['limite_arg'] = limite_arg.get('PAH total')
pah_total['supera_arg'] = pah_total['Valor_num_arg'] > pah_total['limite_arg']

print(f"Puntos de muestreo con panel completo de HAP: {len(pah_total)}")
print(f"Puntos que superan el HAP total (Argentina): {int(pah_total['supera_arg'].sum())}")
pah_total
# Out:
# Puntos de muestreo con panel completo de HAP: 4
# Puntos que superan el HAP total (Argentina): 0
#                       Número de informe Nombre del punto    Fecha  \
# 0  INFORME N° 00055-2019-OEFA/DEAM-SSIM      F01861-SU04  1/15/19
# 1  INFORME N° 00055-2019-OEFA/DEAM-SSIM      F01861-SU05  1/15/19
# 2  INFORME N° 00055-2019-OEFA/DEAM-SSIM      F01861-SU06  1/15/19
# 3  INFORME N° 00055-2019-OEFA/DEAM-SSIM      F01861-SU07  1/15/19
#
#           Hora    Este    Norte  Zona  Valor_num_arg              Parámetro  \
# 0   9:22:00 AM  601338  9506256    18         0.0432  HAP total (calculado)
# 1   9:42:00 AM  601358  9506176    18         0.0432  HAP total (calculado)
# 2  10:04:00 AM  601355  9506171    18         0.0432  HAP total (calculado)
# 3  10:27:00 AM  601354  9506172    18         0.0432  HAP total (calculado)
#
#    limite_arg  supera_arg
# 0        10.0       False
# 1        10.0       False
# 2        10.0       False
# 3        10.0       False

# %% [markdown]
# ## 5.2 Cálculo de excedencias — tabla consolidada
#
# Se reúnen en una sola tabla (formato largo) todas las comparaciones realizadas: cada fila
# es *una* comparación entre un valor medido y un límite normativo (Perú o Argentina), con
# un indicador booleano de si lo supera o no.

# %%
# ============================================================
# 5.2 Tabla consolidada de excedencias (formato largo)
# ============================================================

cols_base = ['Número de informe','Nombre del punto','Fecha','Hora','Este','Norte','Zona','Componente ambiental']

directas_peru = suelo.loc[suelo['limite_peru'].notna(),
                          cols_base + ['Parámetro','Valor_num','limite_peru','supera_peru']].copy()
directas_peru = directas_peru.rename(columns={'Valor_num':'valor','limite_peru':'limite','supera_peru':'supera'})
directas_peru['normativa'] = 'Perú (ECA Suelo)'

directas_arg = suelo.loc[suelo['limite_arg'].notna(),
                         cols_base + ['Parámetro','Valor_num','limite_arg','supera_arg']].copy()
directas_arg = directas_arg.rename(columns={'Valor_num':'valor','limite_arg':'limite','supera_arg':'supera'})
directas_arg['normativa'] = 'Argentina (Decreto 831)'

pah_arg = pah_total.rename(columns={'Valor_num_arg':'valor','limite_arg':'limite','supera_arg':'supera'}).copy()
pah_arg['normativa'] = 'Argentina (Decreto 831)'
pah_arg['Componente ambiental'] = 'Suelo'

excedencias = pd.concat([directas_peru, directas_arg, pah_arg], ignore_index=True)
excedencias['matriz'] = 'Suelo'

print(f"Total de comparaciones realizadas: {len(excedencias)}")
print(f"Total de excedencias detectadas: {int(excedencias['supera'].sum())}")
excedencias.head(10)
# Out:
# Total de comparaciones realizadas: 782
# Total de excedencias detectadas: 247
#                       Número de informe Nombre del punto    Fecha  \
# 0  INFORME N° 00003-2017-OEFA/DEAM-SSIM      F05447-SU01  11/7/17
# 1  INFORME N° 00003-2017-OEFA/DEAM-SSIM      F05447-SU01  11/7/17
# 2  INFORME N° 00003-2017-OEFA/DEAM-SSIM      F05447-SU02  11/7/17
# 3  INFORME N° 00003-2017-OEFA/DEAM-SSIM      F05447-SU02  11/7/17
# 4  INFORME N° 00007-2017-OEFA/DEAM-SSIM      F05461-SU01  11/3/17
# 5  INFORME N° 00007-2017-OEFA/DEAM-SSIM      F05461-SU01  11/3/17
# 6  INFORME N° 00007-2017-OEFA/DEAM-SSIM      F05461-SU02  11/3/17
# 7  INFORME N° 00007-2017-OEFA/DEAM-SSIM      F05461-SU02  11/3/17
# 8  INFORME N° 00009-2017-OEFA/DEAM-SSIM      F05466-SU01  11/7/17
# 9  INFORME N° 00009-2017-OEFA/DEAM-SSIM      F05466-SU01  11/7/17
#
#           Hora    Este    Norte  Zona Componente ambiental  \
# 0  11:12:00 AM  478216  9526380    17                Suelo
# 1  11:12:00 AM  478216  9526380    17                Suelo
# 2  11:21:00 AM  478224  9526389    17                Suelo
# 3  11:21:00 AM  478224  9526389    17                Suelo
# 4   2:41:00 PM  479882  9527330    17                Suelo
# 5   2:41:00 PM  479882  9527330    17                Suelo
# 6   2:53:00 PM  479886  9527336    17                Suelo
# 7   2:53:00 PM  479886  9527336    17                Suelo
# 8   2:55:00 PM  485906  9536489    17                Suelo
# 9   2:55:00 PM  485906  9536489    17                Suelo
#
#                                   Parámetro    valor  limite  supera  \
# 0  Fracciones de Hidrocarburos F2 (C10-C28)    514.0  1200.0   False
# 1  Fracciones de Hidrocarburos F3 (C28-C40)   3795.0  3000.0    True
# 2  Fracciones de Hidrocarburos F2 (C10-C28)      2.5  1200.0   False
# 3  Fracciones de Hidrocarburos F3 (C28-C40)      2.5  3000.0   False
# 4  Fracciones de Hidrocarburos F2 (C10-C28)   2389.0  1200.0    True
# 5  Fracciones de Hidrocarburos F3 (C28-C40)   4039.0  3000.0    True
# 6  Fracciones de Hidrocarburos F2 (C10-C28)    217.0  1200.0   False
# 7  Fracciones de Hidrocarburos F3 (C28-C40)    406.0  3000.0   False
# 8  Fracciones de Hidrocarburos F2 (C10-C28)  17866.0  1200.0    True
# 9  Fracciones de Hidrocarburos F3 (C28-C40)  19066.0  3000.0    True
#
#           normativa matriz
# 0  Perú (ECA Suelo)  Suelo
# 1  Perú (ECA Suelo)  Suelo
# 2  Perú (ECA Suelo)  Suelo
# 3  Perú (ECA Suelo)  Suelo
# 4  Perú (ECA Suelo)  Suelo
# 5  Perú (ECA Suelo)  Suelo
# 6  Perú (ECA Suelo)  Suelo
# 7  Perú (ECA Suelo)  Suelo
# 8  Perú (ECA Suelo)  Suelo
# 9  Perú (ECA Suelo)  Suelo

# %% [markdown]
# ## 5.3 Porcentaje de superación por parámetro y matriz
#
# Para cada parámetro y normativa, se calcula qué porcentaje de las muestras analizadas
# supera el valor de referencia.

# %%
# ============================================================
# 5.3 Porcentaje de superación por parámetro y matriz
# ============================================================

resumen = (excedencias
           .groupby(['matriz','normativa','Parámetro'])
           .agg(n_muestras=('supera','size'), n_supera=('supera','sum'))
           .reset_index())
resumen['%_superacion'] = (resumen['n_supera'] / resumen['n_muestras'] * 100).round(1)
resumen = resumen.sort_values('%_superacion', ascending=False).reset_index(drop=True)

resumen
# Out:
#    matriz                normativa  \
# 0   Suelo  Argentina (Decreto 831)
# 1   Suelo  Argentina (Decreto 831)
# 2   Suelo         Perú (ECA Suelo)
# 3   Suelo         Perú (ECA Suelo)
# 4   Suelo         Perú (ECA Suelo)
# 5   Suelo  Argentina (Decreto 831)
# 6   Suelo         Perú (ECA Suelo)
# 7   Suelo  Argentina (Decreto 831)
# 8   Suelo  Argentina (Decreto 831)
# 9   Suelo  Argentina (Decreto 831)
# 10  Suelo  Argentina (Decreto 831)
# 11  Suelo  Argentina (Decreto 831)
# 12  Suelo         Perú (ECA Suelo)
# 13  Suelo         Perú (ECA Suelo)
# 14  Suelo  Argentina (Decreto 831)
# 15  Suelo  Argentina (Decreto 831)
# 16  Suelo  Argentina (Decreto 831)
# 17  Suelo  Argentina (Decreto 831)
# 18  Suelo  Argentina (Decreto 831)
# 19  Suelo  Argentina (Decreto 831)
# 20  Suelo         Perú (ECA Suelo)
# 21  Suelo  Argentina (Decreto 831)
# 22  Suelo  Argentina (Decreto 831)
# 23  Suelo  Argentina (Decreto 831)
# 24  Suelo         Perú (ECA Suelo)
# 25  Suelo         Perú (ECA Suelo)
# 26  Suelo         Perú (ECA Suelo)
# 27  Suelo         Perú (ECA Suelo)
#
#                                       Parámetro  n_muestras  n_supera  \
# 0   Hidrocarburos totales de petróleo (C10-C40)           6         4
# 1    Hidrocarburos totales de petróleo (C5-C40)           6         4
# 2      Fracciones de Hidrocarburos F2 (C10-C28)         219       113
# 3      Fracciones de Hidrocarburos F3 (C28-C40)         219       110
# 4                                         Bario          15         4
# 5                                         Bario          15         2
# 6       Fracciones de Hidrocarburos F1 (C6-C10)          29         3
# 7                                         Plata          13         1
# 8                                       Berilio          13         1
# 9                                         Cobre          14         1
# 10                                    Molibdeno          14         1
# 11                                     Arsénico          15         1
# 12                                     Arsénico          15         1
# 13                                        Plomo          16         1
# 14                                     Mercurio          15         0
# 15                        HAP total (calculado)           4         0
# 16                                       Cadmio          16         0
# 17                                      Cobalto          14         0
# 18                                  Cromo Total          14         0
# 19                                       Níquel          14         0
# 20                             Benzo (a) Pireno           4         0
# 21                                         Zinc          13         0
# 22                                        Plomo          16         0
# 23                                      Selenio          14         0
# 24                                       Cadmio          16         0
# 25                                  Cromo Total          14         0
# 26                                     Mercurio          15         0
# 27                                    Naftaleno           4         0
#
#     %_superacion
# 0           66.7
# 1           66.7
# 2           51.6
# 3           50.2
# 4           26.7
# 5           13.3
# 6           10.3
# 7            7.7
# 8            7.7
# 9            7.1
# 10           7.1
# 11           6.7
# 12           6.7
# 13           6.2
# 14           0.0
# 15           0.0
# 16           0.0
# 17           0.0
# 18           0.0
# 19           0.0
# 20           0.0
# 21           0.0
# 22           0.0
# 23           0.0
# 24           0.0
# 25           0.0
# 26           0.0
# 27           0.0

# %% [markdown]
# ## 5.4 Mapa interactivo de contaminantes que superan la normativa
#
# Se seleccionan únicamente los puntos de muestreo donde **al menos un contaminante**
# supera la Normativa Peruana y/o la Argentina, y se ubican en un mapa interactivo con
# `folium`. Como las coordenadas de IPASH están en UTM (WGS84, zonas 17S/18S), primero
# se convierten a latitud/longitud.

# %%
# ============================================================
# 5.4a Conversión de coordenadas UTM (WGS84) a Latitud/Longitud
# ============================================================
# Fórmulas de Snyder (1987) para la proyección Transversa de Mercator.
# (No requiere librerías externas como pyproj; si prefieres usar pyproj,
#  puedes reemplazar esta función por `Transformer.from_crs(...)`).

def utm_to_latlon(easting, northing, zone, hemisphere='S'):
    a  = 6378137.0                 # semieje mayor WGS84
    f  = 1 / 298.257223563         # achatamiento WGS84
    e2 = 2*f - f**2
    ep2 = e2 / (1 - e2)
    k0 = 0.9996

    easting  = np.asarray(easting, dtype=float)
    northing = np.asarray(northing, dtype=float)
    zone     = np.asarray(zone, dtype=float)

    x = easting - 500000.0
    y = northing - 10000000.0 if hemisphere == 'S' else northing.copy()

    M  = y / k0
    mu = M / (a * (1 - e2/4 - 3*e2**2/64 - 5*e2**3/256))
    e1 = (1 - np.sqrt(1 - e2)) / (1 + np.sqrt(1 - e2))

    fp = (mu
          + (3*e1/2 - 27*e1**3/32) * np.sin(2*mu)
          + (21*e1**2/16 - 55*e1**4/32) * np.sin(4*mu)
          + (151*e1**3/96) * np.sin(6*mu)
          + (1097*e1**4/512) * np.sin(8*mu))

    C1 = ep2 * np.cos(fp)**2
    T1 = np.tan(fp)**2
    N1 = a / np.sqrt(1 - e2*np.sin(fp)**2)
    R1 = a * (1 - e2) / (1 - e2*np.sin(fp)**2)**1.5
    D  = x / (N1*k0)

    lat_rad = fp - (N1*np.tan(fp)/R1) * (
        D**2/2
        - (5 + 3*T1 + 10*C1 - 4*C1**2 - 9*ep2) * D**4/24
        + (61 + 90*T1 + 298*C1 + 45*T1**2 - 252*ep2 - 3*C1**2) * D**6/720
    )
    lon_rad = (
        D
        - (1 + 2*T1 + C1) * D**3/6
        + (5 - 2*C1 + 28*T1 - 3*C1**2 + 8*ep2 + 24*T1**2) * D**5/120
    ) / np.cos(fp)

    lon0 = np.radians(zone*6 - 183)   # meridiano central de cada zona UTM
    return np.degrees(lat_rad), np.degrees(lon0 + lon_rad)

suelo['lat'], suelo['lon'] = utm_to_latlon(suelo['Este'].values, suelo['Norte'].values,
                                            suelo['Zona'].values, hemisphere='S')
suelo[['Nombre del punto','Este','Norte','Zona','lat','lon']].drop_duplicates().head()
# Out:
#    Nombre del punto    Este    Norte  Zona       lat        lon
# 0       F05447-SU01  478216  9526380    17 -4.284883 -81.196312
# 4       F05447-SU02  478224  9526389    17 -4.284802 -81.196240
# 8       F05461-SU01  479882  9527330    17 -4.276293 -81.181296
# 12      F05461-SU02  479886  9527336    17 -4.276238 -81.181260
# 16      F05466-SU01  485906  9536489    17 -4.193444 -81.126997

# %%
# ============================================================
# 5.4b Selección de puntos con excedencia y mapa folium
# ============================================================

# Solo las comparaciones que SÍ superan la normativa
puntos_excedidos = excedencias[excedencias['supera']].copy()
puntos_excedidos = puntos_excedidos.merge(
    suelo[id_muestra + ['lat','lon']].drop_duplicates(),
    on=id_muestra, how='left'
)

# Resumen por punto de muestreo: cuántas excedencias y de qué tipo
resumen_puntos = []
for (nombre, lat, lon), grupo in puntos_excedidos.groupby(['Nombre del punto','lat','lon']):
    detalle = '<br>'.join(
        f"- {r['Parámetro']} &gt; {r['normativa']} (valor={r['valor']:.2f}, límite={r['limite']:.2f})"
        for _, r in grupo.iterrows()
    )
    resumen_puntos.append({
        'Nombre del punto': nombre, 'lat': lat, 'lon': lon,
        'n_excedencias': len(grupo),
        'detalle': detalle,
        'supera_peru': (grupo['normativa'] == 'Perú (ECA Suelo)').any(),
        'supera_arg':  (grupo['normativa'] == 'Argentina (Decreto 831)').any(),
    })
resumen_puntos = pd.DataFrame(resumen_puntos)

print(f"Puntos de muestreo con al menos una excedencia: {len(resumen_puntos)} de "
      f"{suelo[id_muestra].drop_duplicates().shape[0]} puntos totales")

# Mapa base centrado en el promedio de los puntos con excedencia
mapa_excedencias = folium.Map(
    location=[resumen_puntos['lat'].mean(), resumen_puntos['lon'].mean()],
    zoom_start=8, tiles='CartoDB positron'
)

for _, row in resumen_puntos.iterrows():
    if row['supera_peru'] and row['supera_arg']:
        color = 'red'      # supera ambas normativas
    elif row['supera_peru']:
        color = 'orange'   # supera solo Perú
    else:
        color = 'purple'   # supera solo Argentina

    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=6 + min(row['n_excedencias'], 8),
        color=color, fill=True, fill_color=color, fill_opacity=0.75,
        popup=folium.Popup(
            f"<b>{row['Nombre del punto']}</b><br>{row['n_excedencias']} excedencia(s)<br>{row['detalle']}",
            max_width=350
        ),
        tooltip=row['Nombre del punto']
    ).add_to(mapa_excedencias)

# Leyenda simple
leyenda_html = '''
<div style="position: fixed; bottom: 30px; left: 30px; z-index:9999; background:white;
            padding:10px; border:2px solid grey; border-radius:6px; font-size:13px;">
<b>Excede:</b><br>
<span style="color:orange;">&#9679;</span> Solo Normativa Perú<br>
<span style="color:purple;">&#9679;</span> Solo Normativa Argentina<br>
<span style="color:red;">&#9679;</span> Ambas normativas
</div>
'''
mapa_excedencias.get_root().html.add_child(folium.Element(leyenda_html))

mapa_excedencias
# Out:
# Puntos de muestreo con al menos una excedencia: 131 de 221 puntos totales
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6b8eff77e5c5eb02431a4362c3ca26d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed; bottom: 30px; left: 30px; z-index:9999; background:white;
#             padding:10px; border:2px solid grey; border-radius:6px; font-size:13px;&quot;&gt;
# &lt;b&gt;Excede:&lt;/b&gt;&lt;br&gt;
# &lt;span style=&quot;color:orange;&quot;&gt;&amp;#9679;&lt;/span&gt; Solo Normativa Perú&lt;br&gt;
# &lt;span style=&quot;color:purple;&quot;&gt;&amp;#9679;&lt;/span&gt; Solo Normativa Argentina&lt;br&gt;
# &lt;span style=&quot;color:red;&quot;&gt;&amp;#9679;&lt;/span&gt; Ambas normativas
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6b8eff77e5c5eb02431a4362c3ca26d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6b8eff77e5c5eb02431a4362c3ca26d = L.map(
#                 &quot;map_a6b8eff77e5c5eb02431a4362c3ca26d&quot;,
#                 {
#                     center: [-4.340793818520409, -81.01319672363329],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39e1cc664616a8a62ef5ec72963e6a0f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_39e1cc664616a8a62ef5ec72963e6a0f.addTo(map_a6b8eff77e5c5eb02431a4362c3ca26d);
#
#
#             var circle_marker_9073a463ae8f77ac7bde1e6823536159 = L.circleMarker(
#                 [-4.662027158469078, -81.30915213900848],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.75, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6b8eff77e5c5eb02431a4362c3ca26d);
#
#
#         var popup_d3eca04cbcc3c7160a2d3a7548b0dbd5 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_941a024586c55195b648f44055dafa0a = $(`&lt;div id=&quot;html_941a024586c55195b648f44055dafa0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;F00213-SU01&lt;/b&gt;&lt;br&gt;3 excedencia(s)&lt;br&gt;- Fracciones de Hidrocarburos F1 (C6-C10) &amp;gt; Perú (ECA Suelo) (valor=919.10, límite=200.00)&lt;br&gt;- Fracciones de Hidrocarburos F2 (C10-C28) &amp;gt; Perú (ECA Suelo) (valor=8414.00, límite=1200.00)&lt;br&gt;- Fracciones de Hidrocarburos F3 (C28-C40) &amp;gt; Perú (ECA Suelo) (valor=11799.00, límite=3000.00)&lt;/div&gt;`)[0];
#                 popup_d3eca04cbcc3c7160a2d3a7548b0dbd5.setContent(html_941a024586c55195b648f44055dafa0a);
#
#
#
#         circle_marker_9073a463ae8f77ac7bde1e6823536159.bindPopup(popup_d3eca04cbcc3c7160a2d3a7548b0dbd5)
#         ;
#
#
#
#
#             circle_marker_9073a463ae8f77ac7bde1e6823536159.bindTooltip(
#                 `&lt;div&gt;
#                      F00213-SU01
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_468bc4deceed2fb0f4e3528488b8825c = L.circleMarker(
#                 [-4.662063336857769, -81.3091701873213],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.75, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a6b8eff77e5c5eb02431a4362c3ca26d);
#
#
#         var popup_6ae0462e99062a4dfedcc0d4307bdac3 = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var html_47ba0ebdf84c48dc18a27f411930bef6 = $(`&lt;div id=&quot;html_47ba0ebdf84c48dc18a27f411930bef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;F00213-SU02&lt;/b&gt;&lt;br&gt;3 excedencia(s)&lt;br&gt;- Fracciones de Hidrocarburos F1 (C6-C10) &amp;gt; Perú (ECA Suelo) (valor=1726.00, límite=200.00)&lt;br&gt;- Fracciones de Hidrocarburos F2 (C10-C28) &amp;gt; Perú (ECA Suelo) (valor=13624.00, límite=1200.00)&lt;br&gt;- Fracciones de Hidrocarburos F3 (C28-C40) &amp;gt; Perú (ECA Sue

# %% [markdown]
# ## 5.5 Gráfico de barras: % de superación por parámetro
#
# Barras agrupadas por parámetro, diferenciando la Normativa Peruana y la Argentina,
# solo para los parámetros que registraron al menos una excedencia.

# %%
# ============================================================
# 5.5 Gráfico de barras — % de superación por parámetro
# ============================================================

resumen_graf = resumen[resumen['n_supera'] > 0].copy()

parametros = sorted(resumen_graf['Parámetro'].unique())
normativas = ['Perú (ECA Suelo)', 'Argentina (Decreto 831)']
colores    = {'Perú (ECA Suelo)': '#C8102E', 'Argentina (Decreto 831)': '#74ACDF'}

x = np.arange(len(parametros))
ancho = 0.35

fig, ax = plt.subplots(figsize=(12, 6))
for i, norm in enumerate(normativas):
    valores = []
    for p in parametros:
        fila = resumen_graf[(resumen_graf['Parámetro'] == p) & (resumen_graf['normativa'] == norm)]
        valores.append(fila['%_superacion'].values[0] if len(fila) else 0)
    ax.bar(x + (i - 0.5) * ancho, valores, width=ancho, label=norm, color=colores[norm])

ax.set_xticks(x)
ax.set_xticklabels(parametros, rotation=45, ha='right')
ax.set_ylabel('% de muestras que superan el límite')
ax.set_title('Porcentaje de superación normativa por parámetro (matriz: Suelo)')
ax.legend(title='Normativa')
ax.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
